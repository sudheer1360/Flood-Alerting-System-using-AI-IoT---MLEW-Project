# %%
import pandas as pd

dataset=pd.read_csv('iotdata.csv')

# %%
dataset
# Out:
#       id  rainfall reading  action
# 0      0              1177  normal
# 1      1              1110  normal
# 2      2              4095  normal
# 3      3              4095  normal
# 4      4              4095  normal
# ..   ...               ...     ...
# 395  395              1049  normal
# 396  396              1046  normal
# 397  397              1040  normal
# 398  398              1038  normal
# 399  399              1047  normal
#
# [400 rows x 3 columns]

# %%
X=dataset.iloc[:,1].values

# %%
X=X.reshape(-1,1)

# %%
y=dataset.iloc[:,2].values

# %%
y
# Out:
# array(['normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'normal', 'normal', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'normal',
#        'normal', 'normal', 'normal', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'normal', 'alert',
#        'alert', 'alert', 'alert', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'alert', 'alert', 'alert', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'alert',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'alert', 'alert', 'alert', 'alert', 'alert',
#        'alert', 'alert', 'normal', 'alert', 'alert', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'alert', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

ai=LogisticRegression()
ai.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score

y_answer=ai.predict(X_test)

print(accuracy_score(y_answer,y_test))
# Out:
# 1.0

# %%
import pickle

with open('model.pkl','wb') as model:
    pickle.dump(ai,model)
